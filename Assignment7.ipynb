# %% [markdown]
# # ASSIGNMENT 7

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Salaries.csv")
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# ## QUESTION NUMBER 1

# %%
df[df['TotalPayBenefits'] == df['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN

# %% [markdown]
# ## QUESTION NUMBER 2

# %%
df = df.drop(['Id','Notes','Agency','Status'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = df.drop(['Id','Notes','Agency','Status'],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# ## QUESTION NUMBER 3

# %%
df.JobTitle.str.contains('POLICE')
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
df[df.JobTitle.str.contains('POLICE')]
# Out:
#                   EmployeeName                                 JobTitle  \
# 1                 GARY JIMENEZ          CAPTAIN III (POLICE DEPARTMENT)
# 2               ALBERT PARDINI          CAPTAIN III (POLICE DEPARTMENT)
# 11            PATRICIA JACKSON          CAPTAIN III (POLICE DEPARTMENT)
# 15             RICHARD CORRIEA       COMMANDER III, (POLICE DEPARTMENT)
# 25                GREGORY SUHR                          CHIEF OF POLICE
# ...                        ...                                      ...
# 35131  CYNTHIA HAYNES-EPPERSON  SENIOR POLICE COMMUNICATIONS DISPATCHER
# 35151               LYNN BLOOM                     POLICE SERVICES AIDE
# 35318           ROBERT CHAPMAN                       POLICE OFFICER III
# 35671            RUSSELL MATLI                       POLICE OFFICER III
# 35902               SUSAN ROTH         SERGEANT III (POLICE DEPARTMENT)
#
#          BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# ## QUESTION NUMBER 4

# %%
df['JobTitle'].value_counts().head(10)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# TRANSIT OPERATOR                2388
# Firefighter                     2359
# Recreation Leader               1971
# Patient Care Assistant          1945
# Name: count, dtype: int64

# %% [markdown]
# ## QUESTION NUMBER 5

# %%
df = pd.read_csv("Salaries.csv")
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df1=df.groupby('JobTitle')['TotalPay'].mean().sort_values(ascending=False).head(10)
df1
# Out:
# JobTitle
# GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    399211.275000
# Chief Investment Officer                          339653.700000
# Chief of Police                                   329183.646667
# Chief, Fire Department                            325971.683333
# DEPUTY DIRECTOR OF INVESTMENTS                    307899.460000
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)            302377.730000
# Gen Mgr, Public Trnsp Dept                        297769.413333
# Asst Chf of Dept (Fire Dept)                      281763.483889
# DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      279359.560000
# Dep Dir for Investments, Ret                      278592.545000
# Name: TotalPay, dtype: float64

# %% [markdown]
# ## QUESTION NUMBER 6

# %%
df.groupby('Year')['JobTitle'].nunique()
# Out:
# Year
# 2011    1045
# 2012    1044
# 2013    1051
# 2014     997
# Name: JobTitle, dtype: int64

# %% [markdown]
# ## QUESTION NUMBER 7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.TotalPay
# Out:
# 0         567595.43
# 1         538909.28
# 2         335279.91
# 3         332343.61
# 4         326373.19
#             ...
# 148649         0.00
# 148650         0.00
# 148651         0.00
# 148652         0.00
# 148653      -618.13
# Name: TotalPay, Length: 148654, dtype: float64

# %%
df.TotalPay.astype(float)
# Out:
# 0         567595.43
# 1         538909.28
# 2         335279.91
# 3         332343.61
# 4         326373.19
#             ...
# 148649         0.00
# 148650         0.00
# 148651         0.00
# 148652         0.00
# 148653      -618.13
# Name: TotalPay, Length: 148654, dtype: float64

# %%
df.groupby('Year')['TotalPay'].mean()
# Out:
# Year
# 2011    71744.103871
# 2012    74113.262265
# 2013    77611.443142
# 2014    75463.918140
# Name: TotalPay, dtype: float64

# %% [markdown]
# ## QUESTION NUMBER 8

# %%
df.groupby('Year')['Id'].nunique()
# Out:
# Year
# 2011    36159
# 2012    36766
# 2013    37606
# 2014    38123
# Name: Id, dtype: int64

# %% [markdown]
# ## QUESTION NUMBER 9

# %%
df[df['TotalPay'] > 100000].groupby('Year').size().sort_values(ascending=False)
# Out:
# Year
# 2013    11359
# 2014    11083
# 2012    10001
# 2011     9524
# dtype: int64

# %% [markdown]
# ## QUESTION NUMBER 10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64
